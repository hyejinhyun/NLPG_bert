# %%
import numpy as np
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
import matplotlib.pyplot as plt

#dir 저장
input_dir = '/content/drive/My Drive/pro_data/'
out_dir   = '/content/drive/My Drive/pro_data/output/'
model_dir    = '/content/drive/My Drive/pro_data/'

#score로 rmsle 사용
def rmsle(predicted_values, actual_values):  #정밀도 0에 가까울수록 예측이 좋다
    predicted_values = np.array(predicted_values)
    actual_values = np.array(actual_values)
    print("actual_values\n", actual_values)
    log_predict = np.log(predicted_values + 1)
    log_actual = np.log(actual_values + 1)

    difference = (log_predict - log_actual) ** 2
    print("rmsle_difference\n",difference)

    mean_difference = difference.mean()
    score = np.sqrt(mean_difference)

    return score
rmsle_scorer = make_scorer(rmsle)
print(rmsle_scorer)

#최적 모델 찾기
def learn_models(X_train, y_train, X_test,Y_test):
    i = 0
    #gradient boosting regression 모델에 사용할 파라미터 지정
    param_grid_gbr = {
        "n_estimators": [2000,3000,4000,5000],
        'learning_rate':[0.01,0.05, 0.1],
        'alpha' :[0.1,0.2,0.3]
    }
    #xgboost regression 모델에 사용할 파라미터 지정
    param_xgr = {
        'learning_rate': [0.06],
        'max_depth': [2, 3],
        'n_estimators': [40000],
        'colsample_bytree': [0.5, 1],
    }
    #cross validation 지정
    shuffle_cv = KFold(n_splits=10, shuffle=True, random_state=2019)
    models = [GradientBoostingRegressor(),xgb.XGBRegressor()]
    model_names =["gbr",'xgr']
    param_grid = [param_grid_gbr,param_xgr]
    rmsle_s =[]

    #모델별로 최적의 하이퍼파라미터 찾기
    for model in models:
        grid_search = GridSearchCV(model, param_grid=param_grid[i], cv=shuffle_cv, n_jobs=1, verbose=2,
                                   scoring=rmsle_scorer)
        grid_search.fit(X_train, y_train)     #train
        prediction = grid_search.predict(X_test)  # 검증을 위한 테스트
        score = grid_search.best_score_           # 최고 점수 저장
        print(model_names[i] + "최고 점수 : ", score)
        print(model_names[i] + "최고 점수를 낸 파라미터 : ", grid_search.best_params_)
        print(model_names[i] + "최고 점수를 낸 파라미터를 가진 모형 : ", grid_search.best_estimator_)
        rmsle_s.append(score)
        joblib.dump(grid_search, model_dir + f'{model_names[i]}_log_reg.pkl') # 최고 점수를 낸 모델 저장
        i += 1
    d = {'Model': model_names, 'RMSLE': rmsle_s}
    print("d==",d)
    #gbr 최고 성능 모델과 xgr 최고 성능 모델 스코어 비교 후 더 좋은 모델 이름 return
    if rmsle_s[0] < rmsle_s[1]:
        print('best: '+model_names[0]+str(rmsle_s[0]))
        return model_names[0]
    else:
        print('best: '+model_names[1]+str(rmsle_s[1]))
        return model_names[1]

scaler = MinMaxScaler()
#예측 함수
def predict_data():
    pred_raw =pd.read_csv(input_dir + "nspdatatest12.csv")
    Xp = pred_raw.iloc[:, 0:2]
    Xp_scale = scaler.transform(Xp)
    #저장해놓은 최고 성능 모델 load
    grid_from_joblib = joblib.load(model_dir+f'{best_model}_log_reg.pkl')
    test_y_pred = grid_from_joblib.predict(Xp_scale)  #predict

    pred_df05 = pd.DataFrame()
    pred_df05['test_y_pred'] = test_y_pred
    pred_df05.to_csv(out_dir+'nsp_predict.csv')

#사용할 data 불러오기
dataset = pd.read_csv('/content/drive/My Drive/pro_data/nspdata12.csv')

#X, Y 편집
X = dataset.iloc[:,:2] #독립변수
X = X.dropna(axis=0)   #null 값 제거
print(X.head())
Y = dataset['correct'] #종속변수
Y = Y.dropna(axis=0)   #null 값 제거
print(Y.head())
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state

# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000
# [05:00:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.6082692  0.3992698  0.45564282 0.4844376 ]
# rmsle_difference
#  [0.0045288  0.00290812 0.00035166 0.00696258]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000, total=   1.1s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000
# [05:00:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.6064129  0.48539555 0.38915145 0.5426195 ]
# rmsle_difference
#  [0.02675911 0.00689939 0.01092378 0.0037998 ]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000
# [05:00:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.32352224 0.3356551  0.39993936 0.37591147]
# rmsle_difference
#  [6.21797412e-05 2.81997344e-03 5.31374484e-03 1.34195473e-02]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=2, n_estimators=40000, total=   1.1s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.40417844 0.45032582 0.6939123  0.5252666 ]
# rmsle_difference
#  [7.64996340e-06 4.25148985e-05 1.83159917e-02 3.01612271e-02]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.1s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.45285416 0.54248196 0.38134223 0.4040116 ]
# rmsle_difference
#  [0.00184393 0.02456941 0.00023761 0.0016214 ]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.1s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.53760815 0.5651997  0.48863596 0.32274538]
# rmsle_difference
#  [3.49038075e-07 2.85230770e-03 1.83362808e-02 1.91023304e-02]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.48758826 0.406081   0.40341413 0.5378038 ]
# rmsle_difference
#  [1.45408968e-02 3.89316692e-04 3.61687640e-03 4.62701234e-05]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.1s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.5030897  0.41816568 0.435732   0.4375775 ]
# rmsle_difference
#  [0.00170216 0.01283689 0.01076528 0.00164055]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.5008098  0.49362758 0.49267945 0.47851673]
# rmsle_difference
#  [0.00810484 0.01014711 0.0011691  0.00636428]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.44477123 0.46589547 0.45362484 0.40404603]
# rmsle_difference
#  [1.12265547e-03 6.41654730e-05 8.35300944e-05 1.06344534e-04]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.59514093 0.3925308  0.43860704 0.4990504 ]
# rmsle_difference
#  [3.49279420e-03 3.45212290e-03 4.87249059e-05 8.69331237e-03]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.5932896  0.5022688  0.43180162 0.48824173]
# rmsle_difference
#  [0.02414272 0.00890342 0.005517   0.00066337]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.0s
# [CV] colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000
# [05:00:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# actual_values
#  [0.322281  0.4118747 0.4568501 0.3446802]
# rmsle_difference
#  [7.78573236e-05 5.72717324e-06 1.09215088e-03 1.92662688e-02]
# [CV]  colsample_bytree=1, learning_rate=0.06, max_depth=3, n_estimators=40000, total=   1.1s
# [05:00:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   42.4s finished
# xgr_최고 점수 :  0.08351729535036527
# xgr_최고 점수를 낸 파라미터 :  {'colsample_bytree': 0.5, 'learning_rate': 0.06, 'max_depth': 2, 'n_estimators': 40000}
# xgr_최고 점수를 낸 파라미터를 가진 모형 :  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.5, gamma=0,
#              importance_type='gain', learning_rate=0.06, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=None, n_estimators=40000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)
# (5, 2)
# d==== {'Modelling Algo': ['gbr', 'xgr'], 'RMSLE': [0.0767116125602502, 0.08351729535036527]}
# best: gbr0.0767116125602502

# %%
import numpy as np
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
import matplotlib.pyplot as plt

#dir 저장
input_dir = '/content/drive/My Drive/pro_data/'
out_dir   = '/content/drive/My Drive/pro_data/output/'
model_dir    = '/content/drive/My Drive/pro_data/'

#최적 모델 찾기
def learn_models(X_train, y_train, X_test,Y_test):
    i = 0
    param_grid_gbr = {
        "n_estimators": [100,500,1000,3000, 5000],
        'learning_rate':[0.01,0.05, 0.1],
        'subsample' :[0.5,0.7,0.9]
    }
    param_xgr = {
        'learning_rate': [0.01, 0.05, 0.1],
        'max_depth': [2, 3],
        'subsample' :[0.5,0.7,0.9],
        'colsample_bytree': [0.5, 1],
    }
    shuffle_cv = KFold(n_splits=5, shuffle=True, random_state=2019)
    models = [GradientBoostingClassifier(random_state=2019),xgb.XGBClassifier()]  #Classifier
    model_names =["gbr",'xgr']
    param_grid = [param_grid_gbr,param_xgr]
    accu_s =[]
    for model in models:
        grid_search = GridSearchCV(model, param_grid=param_grid[i], cv=shuffle_cv, n_jobs=1, verbose=5,
                                   scoring='accuracy')
        grid_search.fit(X_train, y_train)
        prediction = grid_search.predict(X_test)  # 검증을 위한 테스트
        score = grid_search.best_score_
        print(model_names[i] + "최고 점수 : ", score)
        print(model_names[i] + "최고 점수를 낸 파라미터 : ", grid_search.best_params_)
        print(model_names[i] + "최고 점수를 낸 파라미터를 가진 모형 : ", grid_search.best_estimator_)
        accu_s.append(score)
        joblib.dump(grid_search, model_dir + f'{model_names[i]}_cl.pkl')
        i += 1
    d = {'Model': model_names, 'Accuracy': accu_s}
    print("d==",d)
    if accu_s[0] > accu_s[1]:
        print('best: '+model_names[0]+str(accu_s[0]))
        return model_names[0]
    else:
        print('best: '+model_names[1]+str(accu_s[1]))
        return model_names[1]

scaler = StandardScaler()
def predict_data():
    pred_raw=pd.read_csv(input_dir + "nspdatatestcl.csv")
    Xp = pred_raw.iloc[:, 0:2]
    Xp_scale = scaler.transform(Xp)
    grid_from_joblib = joblib.load(model_dir+f'{best_model}_cl.pkl')
    if best_model == 'xgr':
      Xp.columns = ['f0', 'f1']
    test_y_pred = grid_from_joblib.predict(Xp_scale)
    pred_df = pd.DataFrame()
    pred_df['test_y_pred'] = test_y_pred
    pred_df.to_csv(out_dir+'nsp_predictcl2.csv')


dataset = pd.read_csv('/content/drive/My Drive/pro_data/nspdataclv2.csv')

X = dataset.iloc[:,:2]
X = X.dropna(axis=0)
print(X.head())
Y = dataset['correct']
Y = Y.dropna(axis=0)
print(Y.head())
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=1004)
scaler = MinMaxScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

best_model = learn_models(X_train_scale, Y_train, X_test_scale, Y_test)

predict_data()
# Out:
#      onetwo  twothree
# 0  0.435944  0.448416
# 1  0.459359  0.452463
# 2  0.387551  0.443144
# 3  0.452032  0.455800
# 4  0.453465  0.456102
# 0    1.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    0.0
# Name: correct, dtype: float64
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.5, score=0.875, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.5, score=0.500, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.5, score=0.375, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.5 .............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.5, score=0.750, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.5, score=0.875, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.7, score=0.750, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.7, score=0.750, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.7 .............
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.7, score=0.375, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.7, score=0.750, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.7, score=0.875, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.9, score=0.875, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.9, score=0.750, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.9, score=0.500, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.9, score=0.750, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=100, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=100, subsample=0.9, score=0.875, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.5, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.5, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.5, score=0.375, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.5, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.5 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.5, score=0.875, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.7, score=0.625, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.7, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.7, score=0.625, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.7, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.7 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.7, score=0.875, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.9, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.9, score=0.625, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.9, score=0.625, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.9, score=0.750, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=500, subsample=0.9 .............
# [CV]  learning_rate=0.01, n_estimators=500, subsample=0.9, score=0.875, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=1000, subsample=0.5 ............
# [CV]  learning_rate=0.01, n_estimators=1000, subsample=0.5, score=0.750, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=1000, subsample=0.5 ............
# [CV]  learning_rate=0.01, n_estimators=1000, subsample=0.5, score=0.750, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=1000, subsample=0.5 ............
# [CV]  learning_rate=0.01, n_estimators=1000, subsample=0.5, score=0.375, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=1000, subsample=0.5 ............
# [CV]  learning_rate=0.01, n_estimators=1000, subsample=0.5, score=0.750, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=1000, subsample=0.5 ............
# [CV]  learning_rate=0.01, n_estimators=1000, subsample=0

# [CV] learning_rate=0.1, n_estimators=100, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.5, score=0.750, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.5, score=0.875, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.7, score=0.625, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.7, score=0.750, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.7, score=0.500, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.7, score=0.750, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.7, score=0.875, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.9, score=0.625, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.9, score=0.625, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.9, score=0.625, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.9, score=0.750, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=100, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=100, subsample=0.9, score=0.875, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.5, score=0.750, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.5, score=0.750, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.5, score=0.500, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.5, score=0.750, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.5 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.5, score=0.875, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.7, score=0.750, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.7, score=0.625, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.7, score=0.500, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.7, score=0.750, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.7 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.7, score=0.875, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.9, score=0.625, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.9, score=0.625, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.9, score=0.625, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.9, score=0.750, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=500, subsample=0.9 ..............
# [CV]  learning_rate=0.1, n_estimators=500, subsample=0.9, score=0.875, total=   0.3s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.5, score=0.750, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.5, score=0.750, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.5, score=0.500, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.5, score=0.750, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.5, score=0.875, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.7, score=0.750, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.7, score=0.625, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.7, score=0.500, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.7, score=0.750, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.7, score=0.875, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.9, score=0.625, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.9, score=0.625, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.9, score=0.625, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.9, score=0.750, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=1000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=1000, subsample=0.9, score=0.875, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.5, score=0.750, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.5, score=0.750, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.5, score=0.500, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.5, score=0.750, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.5, score=0.875, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.7, score=0.750, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.7, score=0.625, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.7, score=0.500, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.7, score=0.750, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.7, score=0.875, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.9, score=0.625, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.9, score=0.625, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.9, score=0.625, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.9, score=0.750, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=3000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=3000, subsample=0.9, score=0.875, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.5, score=0.750, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.5, score=0.750, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.5, score=0.500, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.5, score=0.750, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.5 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.5, score=0.875, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.7, score=0.750, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.7, score=0.625, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.7, score=0.500, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.7, score=0.750, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.7 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.7, score=0.875, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.9, score=0.625, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.9, score=0.625, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.9, score=0.625, total=   1.8s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.9, score=0.750, total=   1.7s
# [CV] learning_rate=0.1, n_estimators=5000, subsample=0.9 .............
# [CV]  learning_rate=0.1, n_estimators=5000, subsample=0.9, score=0.875, total=   1.7s
# gbr_최고 점수 :  0.775
# gbr_최고 점수를 낸 파라미터 :  {'learning_rate': 0.05, 'n_estimators': 100, 'subsample': 0.7}
# gbr_최고 점수를 낸 파라미터를 가진 모형 :  GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.05, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=2019, subsample=0.7, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# (5, 2)
# [Parallel(n_jobs=1)]: Done 225 out of 225 | elapsed:  2.8min finished
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.875, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.875, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.875, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.375, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=0.5, learning_rate=0.05, max_depth=3, subsample=0.9
# ...
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.01, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.7, score=0.875, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.7, score=0.875, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.05, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.7, score=0.875, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=2, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5, score=0.375, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.5, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7, score=0.625, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.7, score=0.875, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9, score=0.500, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9
# [CV]  colsample_bytree=1, learning_rate=0.1, max_depth=3, subsample=0.9, score=0.750, total=   0.0s
# xgr_최고 점수 :  0.7
# xgr_최고 점수를 낸 파라미터 :  {'colsample_bytree': 1, 'learning_rate': 0.05, 'max_depth': 3, 'subsample': 0.9}
# xgr_최고 점수를 낸 파라미터를 가진 모형 :  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.9, verbosity=1)
# (5, 2)
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    1.8s finished
# d==== {'Modelling Algo': ['gbr', 'xgr'], 'Accuracy': [0.775, 0.7]}
# best: gbr0.775
